# %%
import pandas as pd
df = pd.read_csv('netflix.csv')

# %% [markdown]
# ### 1. Basic Metrics Analysis

# %%
df.head()
# Out:
#   show_id     type                  title         director
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country
# 0                                                NaN  United States  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration
# 0  September 25, 2021          2020  PG-13     90 min  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### 2. Observations on the shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required), missing value detection, statistical summary

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include='all')
# Out:
#        show_id   type                 title       director
# count     8807   8807                  8807           6173  \
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year
# count                 7982           7976             8797   8807.000000  \
# unique                7692            748             1767           NaN
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ###  3.	Non-Graphical Analysis: Value counts and unique attributes

# %%
df['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
df['release_year'].nunique()
# Out:
# 74

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### 4.	Visual Analysis - Univariate, Bivariate after pre-processing of the data.

# %% [markdown]
# #### Pre-processing of the data
# 1. Handling null values
# 2. Un-nesting the columns

# %% [markdown]
# **Handling null values**

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.director.fillna('Unknown Director', inplace=True)
df.cast.fillna('Unknown Cast', inplace=True)
df.country.fillna('Unknown Country', inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df.dropna(subset=["date_added", "rating",'duration'], inplace=True)
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.shape
# Out:
# (8790, 12)

# %%
df.head()
# Out:
#   show_id     type                  title          director
# 0      s1    Movie   Dick Johnson Is Dead   Kirsten Johnson  \
# 1      s2  TV Show          Blood & Water  Unknown Director
# 2      s3  TV Show              Ganglands   Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Unknown Director
# 4      s5  TV Show           Kota Factory  Unknown Director
#
#                                                 cast          country
# 0                                       Unknown Cast    United States  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Unknown Country
# 3                                       Unknown Cast  Unknown Country
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            India
#
#            date_added  release_year rating   duration
# 0  September 25, 2021          2020  PG-13     90 min  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# **Un-nesting the columns**

# %%
small_df = df[[ 'title','cast']]

# %%
def split_my_str(inp):
    return str(inp).split(', ')

# %%
small_df['cast'] = small_df.cast.apply(split_my_str)
small_df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13276\3528099320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['cast'] = small_df.cast.apply(split_my_str)
#                       title                                               cast
# 0      Dick Johnson Is Dead                                     [Unknown Cast]
# 1             Blood & Water  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...
# 2                 Ganglands  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...
# 3     Jailbirds New Orleans                                     [Unknown Cast]
# 4              Kota Factory  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...
# ...                     ...                                                ...
# ...

# %%
df_cast= small_df.explode('cast')
df_cast.head()
# Out:
#                    title                                               cast
# 0   Dick Johnson Is Dead                                       Unknown Cast
# 1          Blood & Water  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2              Ganglands  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3  Jailbirds New Orleans                                       Unknown Cast
# 4           Kota Factory  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...

# %%
df_cast=df_cast[df_cast.cast!='Unknown Cast]']
#excluding "Unknown Cast" column as it will optimize the data and does not affect our analysis
df_cast.head()
# Out:
#                    title                                               cast
# 0   Dick Johnson Is Dead                                       Unknown Cast
# 1          Blood & Water  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2              Ganglands  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3  Jailbirds New Orleans                                       Unknown Cast
# 4           Kota Factory  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...

# %%
df_cast.cast.nunique()
# Out:
# 7679

# %%
 #top 10 Cast Names with highest number of Contents
df_cast.cast.value_counts()[:10]
# Out:
# cast
# Unknown Cast                                                                                                              825
# David Attenborough                                                                                                         19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                    14
# Samuel West                                                                                                                10
# Jeff Dunham                                                                                                                 7
# David Spade, London Hughes, Fortune Feimster                                                                                6
# Michela Luci, Jamie Watson, Eric Peterson, Anna Claire Bartlam, Nicolas Aqui, Cory Doran, Julie Lemieux, Derek McGrath      6
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df_cast.cast.value_counts()[:10].plot(kind='bar')
plt.xlabel('Name of the Actor')
plt.title('Actor/Content count ')
plt.ylabel('Total number of Contents')
plt.show()

# %%
small_df
# Out:
#                       title                                               cast
# 0      Dick Johnson Is Dead                                     [Unknown Cast]
# 1             Blood & Water  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...
# 2                 Ganglands  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...
# 3     Jailbirds New Orleans                                     [Unknown Cast]
# 4              Kota Factory  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...
# ...                     ...                                                ...
# 8802                 Zodiac  [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...
# 8803            Zombie Dumb                                     [Unknown Cast]
# 8804             Zombieland  [Jesse Eisenberg, Woody Harrelson, Emma Stone,...
# 8805                   Zoom  [Tim Allen, Courteney Cox, Chevy Chase, Kate M...
# 8806                 Zubaan  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...
#
# [8790 rows x 2 columns]

# %%
df_cast.cast.value_counts()[:10].plot(kind='bar')
plt.show()

# %%
small_dfd = df[[ 'title','director']]
small_dfd['director'] = small_dfd.director.apply(split_my_str)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13276\1452391600.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_dfd['director'] = small_dfd.director.apply(split_my_str)

# %%
df_dir = small_dfd.explode('director')

# %%
df_dir['director'].nunique()
# Out:
# 4992

# %%
df_dir=df_dir[df_dir.director!='Unknown Director']
#excluding "Unknown Director" column as it will optimize the data and does not affect our analysis
df_dir.head()
# Out:
#                               title         director
# 0              Dick Johnson Is Dead  Kirsten Johnson
# 2                         Ganglands  Julien Leclercq
# 5                     Midnight Mass    Mike Flanagan
# 6  My Little Pony: A New Generation    Robert Cullen
# 6  My Little Pony: A New Generation   José Luis Ucha

# %%
df_dir['director'].value_counts()[:10]
# Out:
# director
# Unknown Director       2621
# Rajiv Chilaka            22
# Jan Suter                21
# Raúl Campos              19
# Marcus Raboy             16
# Suhas Kadav              16
# Jay Karas                15
# Cathy Garcia-Molina      13
# Martin Scorsese          12
# Youssef Chahine          12
# Name: count, dtype: int64

# %%
df_dir['director'].value_counts()[:10].plot(kind='bar')
plt.xlabel('Director Name')
plt.title('Director/Content count ')
plt.ylabel('Total Content')
plt.show()

# %%
small_dfc = df[['title', 'country']]
small_dfc['country'] = small_dfc.country.apply(split_my_str)
small_dfc.head(10)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13276\1489369765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_dfc['country'] = small_dfc.country.apply(split_my_str)
#                               title
# 0              Dick Johnson Is Dead  \
# 1                     Blood & Water
# 2                         Ganglands
# 3             Jailbirds New Orleans
# 4                      Kota Factory
# 5                     Midnight Mass
# 6  My Little Pony: A New Generation
# 7                           Sankofa
# 8     The Great British Baking Show
# 9                      The Starling
#
#                                              country
# 0                                    [United States]
# ...

# %%
df_con = small_dfc.explode('country')

# %%
df_con=df_con[df_con.country!='Unknown Country']
#excluding "Unknown Director" column as it will optimize the data and does not affect our analysis

# %%
df_con.country.nunique()
# Out:
# 128

# %%
df_con['country'].value_counts()[:10]
# Out:
# country
# United States     3680
# India             1046
# United Kingdom     803
# Canada             445
# France             393
# Japan              316
# Spain              232
# South Korea        231
# Germany            226
# Mexico             169
# Name: count, dtype: int64

# %%
df_con['country'].value_counts()[:10].plot(kind='bar')
plt.xlabel('Country Name')
plt.title('Country/Content count ')
plt.ylabel('Total Content')
plt.show()

# %%
sns.boxplot(data = df, x = 'type', y = 'release_year')
# Out:
# <Axes: xlabel='type', ylabel='release_year'>

# %%
df_a1  = df[['type','cast','country','director','release_year']]
df_a1
# Out:
#       type                                               cast
# 0        0                                       Unknown Cast  \
# 1        1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2        1  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3        1                                       Unknown Cast
# 4        1  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...    ...                                                ...
# 8802     0  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803     1                                       Unknown Cast
# 8804     0  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805     0  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806     0  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#               country          director  release_year
# 0       United States   Kirsten Johnson          2020
# 1        South Africa  Unknown Director          2021
# 2     Unknown Country   Julien Leclercq          2021
# ...

# %%
df['type'].replace(['Movie', 'TV Show'],[0, 1], inplace=True)
#converting categorical column into numeric column to compare 2 variables

# %%
sns.pairplot(df_a1)

# %%
df_a2  = df[['type','release_year']].head(10)
df_a2
sns.heatmap(df_a2)
# Out:
# <Axes: >

# %%
df.type.value_counts()# 0 for 'Movies' and 1 for 'TV Shows'
# Out:
# type
# 0    6126
# 1    2664
# Name: count, dtype: int64

# %%
df.show_id
# Out:
# 0          s1
# 1          s2
# 2          s3
# 3          s4
# 4          s5
#         ...
# 8802    s8803
# 8803    s8804
# 8804    s8805
# 8805    s8806
# 8806    s8807
# Name: show_id, Length: 8790, dtype: object

# %%
df.release_year.value_counts()
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
df_con['country'].value_counts()[:10]
# Out:
# country
# United States     3680
# India             1046
# United Kingdom     803
# Canada             445
# France             393
# Japan              316
# Spain              232
# South Korea        231
# Germany            226
# Mexico             169
# Name: count, dtype: int64

# %%
df.country.nunique()
# Out:
# 749

# %%
df_dir.nunique()
# Out:
# title       6169
# director    4991
# dtype: int64

# %%
df_dir.director.value_counts()
# Out:
# director
# Rajiv Chilaka     22
# Jan Suter         21
# Raúl Campos       19
# Suhas Kadav       16
# Marcus Raboy      16
#                   ..
# Raymie Muzquiz     1
# Stu Livingston     1
# Joe Menendez       1
# Eric Bross         1
# Mozez Singh        1
# Name: count, Length: 4991, dtype: int64

# %%
df_cast.cast.value_counts()
# Out:
# cast
# Anupam Kher              43
# Shah Rukh Khan           35
# Julie Tejwani            33
# Naseeruddin Shah         32
# Takahiro Sakurai         32
#                          ..
# Julissa Calderon          1
# Karrie Martin             1
# Ted Kaczynski             1
# Tonya Kay                 1
# Chittaranjan Tripathy     1
# Name: count, Length: 36392, dtype: int64

# %%
df_year.duration=df_year.duration.apply(split_string1)
df_ea.head()

# %%
# !pip install wordcloud
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_dir1=df[df.director!='Unknown Director']
df_dir1
# Out:
#      show_id     type                             title
# 0         s1    Movie              Dick Johnson Is Dead  \
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director
# 0                   Kirsten Johnson  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
df = df_dir.groupby('director')
df.get_group('A. L. Vijay').nunique()
# Out:
# title       2
# director    1
# dtype: int64

# %%
df = df_dir.groupby('director')
df.first()
# Out:
#                                        title
# director
# A. L. Vijay                         Watchman
# A. Raajdheep                      Asura Guru
# A. Salaam                          Salaakhen
# A.R. Murugadoss                       Sarkar
# Aadish Keluskar      Jaoon Kahan Bata Ae Dil
# ...                                      ...
# Éric Warin                             Leap!
# Ísold Uggadóttir        And Breathe Normally
# Óskar Thór Axelsson               Ég man þig
# Ömer Faruk Sorak                     G.O.R.A
# Şenol Sönmez                   Hayat Öpücügü
#
# [4991 rows x 1 columns]

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[431], line 1
# ----> 1 df.info()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'info'

# %%
df_list  = df[['title','listed_in']]
def split_my_str(inp):
    return str(inp).split(', ')

# %%
df_list.listed_in.apply(split_my_str)
df_list
# Out:
#                       title                                          listed_in
# 0      Dick Johnson Is Dead                                      Documentaries
# 1             Blood & Water    International TV Shows, TV Dramas, TV Mysteries
# 2                 Ganglands  Crime TV Shows, International TV Shows, TV Act...
# 3     Jailbirds New Orleans                             Docuseries, Reality TV
# 4              Kota Factory  International TV Shows, Romantic TV Shows, TV ...
# ...                     ...                                                ...
# 8802                 Zodiac                     Cult Movies, Dramas, Thrillers
# 8803            Zombie Dumb             Kids' TV, Korean TV Shows, TV Comedies
# 8804             Zombieland                            Comedies, Horror Movies
# 8805                   Zoom                 Children & Family Movies, Comedies
# 8806                 Zubaan     Dramas, International Movies, Music & Musicals
#
# [8807 rows x 2 columns]

# %%
df_list['listed_in'] = df_list.listed_in.apply(split_my_str)
df_list.head()
# Out:
#                    title                                          listed_in
# 0   Dick Johnson Is Dead                                    [Documentaries]
# 1          Blood & Water  [International TV Shows, TV Dramas, TV Mysteries]
# 2              Ganglands  [Crime TV Shows, International TV Shows, TV Ac...
# 3  Jailbirds New Orleans                           [Docuseries, Reality TV]
# 4           Kota Factory  [International TV Shows, Romantic TV Shows, TV...

# %%
l1 =df_list.explode('listed_in')
l1
# Out:
#                      title                 listed_in
# 0     Dick Johnson Is Dead             Documentaries
# 1            Blood & Water    International TV Shows
# 1            Blood & Water                 TV Dramas
# 1            Blood & Water              TV Mysteries
# 2                Ganglands            Crime TV Shows
# ...                    ...                       ...
# 8805                  Zoom  Children & Family Movies
# 8805                  Zoom                  Comedies
# 8806                Zubaan                    Dramas
# 8806                Zubaan      International Movies
# 8806                Zubaan          Music & Musicals
#
# [19323 rows x 2 columns]

# %%
l1['listed_in'].value_counts()[:10]
# Out:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in l1['listed_in'])
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200, background_color="pink").generate(text)
plt.figure(figsize=(20,15))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.title('Most Popular Genre movies',fontsize = 20)
plt.axis("off")
plt.show()

# %%
df['date_added'].value_counts()
# Out:
# date_added
# January 1, 2020      109
# November 1, 2019      89
# March 1, 2018         75
# December 31, 2019     74
# October 1, 2018       71
#                     ...
# December 4, 2016       1
# November 21, 2016      1
# November 19, 2016      1
# November 17, 2016      1
# January 11, 2020       1
# Name: count, Length: 1767, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df
# Out:
#      show_id     type                  title         director
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...
